# %% [raw]
# ---
# title: "Standard Atmosphere"
# format:
#   html:
#     code-fold: false
# toc: true
# number-sections: true
# jupyter: python3
# ---

# %% [markdown]
# # Let's take a look at the **standard atmosphere**.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(10)
y = np.square(x)

# %%
fig, ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %% [markdown]
# # Let's try another section
